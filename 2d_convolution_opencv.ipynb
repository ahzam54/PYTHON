# %% [markdown]
# <a href="https://colab.research.google.com/github/ahzam54/PYTHON/blob/master/2d_convolution_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2d convolution**
#
# *  Sliding a kernel matrix and doing element wise multiplucation on the input image
#
# ### why do we need 2d convolution
#
# *  smoothing/blurring images
# *  Feature extraction
# *  Image enhancement
# *  Edge detction![Screenshot 2025-07-06 022257.png](data:image/png;base64,...)
#
# ### How does 2d convolu

# %%
import cv2 as cv
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2 as cv
import os
import numpy as np
import matplotlib.pyplot as plt

def convolution2d():
  root = os.getcwd()
  imgpath = os.path.join(root,'cat.jpg')
  img = cv.imread(imgpath)
  imgRGB = cv.cvtColor(img,cv.COLOR_BGR2RGB)

  n = 15
  kernal = np.ones((n,n),np.float32)/(n*n)
  imgFilter = cv.filter2D(imgRGB,-1,kernal)

  kernel_edge_x = np.array([[-1, 0, 1],
                              [-2, 0, 2],
                              [-1, 0, 1]])
  edge_x = cv.filter2D(imgRGB, -1, kernel_edge_x)

  # Create a figure with a 1x3 grid for subplots
  plt.figure(figsize=(15, 5))

  plt.subplot(131)
  plt.title("Edge Detection (Sobel X)")
  plt.imshow(edge_x)

  plt.subplot(132)
  plt.title("Smoothed Image")
  plt.imshow(imgFilter)

  plt.subplot(133)
  plt.title("Original Image")
  plt.imshow(imgRGB)

  plt.tight_layout() # Adjust layout to prevent titles overlapping
  plt.show()

# %%
if __name__ == '__main__':
  convolution2d()
