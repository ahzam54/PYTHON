# %% [markdown]
# <a href="https://colab.research.google.com/github/ahzam54/PYTHON/blob/master/yolo_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ultralytics import YOLO
import cv2 as cv
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('../Yolo-Weights/yolov8n.pt')
result = model("cat.jpg", show=True) # Change show=True to save=True
#cv.waitKey(0) # Remove waitKey
# cv.destroyAllWindows() # Remove destroyAllWindows
# Out:
# image 1/1 /content/cat.jpg: 448x640 1 cat, 174.9ms
# Speed: 3.6ms preprocess, 174.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
import matplotlib.pyplot as plt
import cv2

# Load the image (assuming it was saved in the 'runs/detect/predict' directory by default)
# You might need to adjust the path based on where the YOLO model saved the output.
img_path = 'runs/detect/predict/cat.jpg' # Default save location for YOLO
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Convert BGR to RGB for matplotlib

# Display the image
plt.imshow(img)
plt.axis('off') # Hide axes
plt.show()
